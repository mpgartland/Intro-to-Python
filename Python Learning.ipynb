# %% [markdown]
# # Myles Notebook

# %%
2+2
# Out:
# 4

# %%
print "Hello World"
# Out:
# Hello World

# %% [markdown]
# ##### Go Chiefs

# %%
x=5

# %%
y=(1,2,8,5,10)

# %%
y
# Out:
# (1, 2, 8, 5, 10)

# %%
from __future__ import division
from numpy.random import randn
import numpy as np
import os
import matplotlib.pyplot as plt
np.random.seed(12345)
plt.rc('figure', figsize=(10, 6))
from pandas import Series, DataFrame
import pandas as pd
np.set_printoptions(precision=4)
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# %pwd
# Out:
# u'/Users/mylesgartland/Documents/Courses/Data Mining/Intro to Python/Python notebook items'

# %%
dia=pd.read_csv('data/diamonds.csv')

# %%
dia
# Out:
#      CARAT COLOR CLARITY CERT  PRICE
# 0     0.30     D     VS2  GIA   1302
# 1     0.30     E     VS1  GIA   1510
# 2     0.30     G    VVS1  GIA   1510
# 3     0.30     G     VS1  GIA   1260
# 4     0.31     D     VS1  GIA   1641
# 5     0.31     E     VS1  GIA   1555
# 6     0.31     F     VS1  GIA   1427
# 7     0.31     G    VVS2  GIA   1427
# 8     0.31     H     VS2  GIA   1126
# 9     0.31     I     VS1  GIA   1126
# 10    0.32     F     VS1  GIA   1468
# 11    0.32     G     VS2  GIA   1202
# 12    0.33     E     VS2  GIA   1327
# 13    0.33     I     VS2  GIA   1098
# 14    0.34     E     VS1  GIA   1693
# 15    0.34     F     VS1  GIA   1551
# 16    0.34     G     VS1  GIA   1410
# 17    0.34     G     VS2  GIA   1269
# 18    0.34     H     VS1  GIA   1316
# 19    0.34     H     VS2  GIA   1222
# 20    0.35     E     VS1  GIA   1738
# 21    0.35     F     VS1  GIA   1593
# 22    0.35     G     VS1  GIA   1447
# 23    0.35     H     VS2  GIA   1255
# 24    0.36     F     VS1  GIA   1635
# 25    0.36     H    VVS2  GIA   1485
# 26    0.37     F     VS2  GIA   1420
# 27    0.37     H     VS1  GIA   1420
# 28    0.40     F     VS1  GIA   1911
# 29    0.40     H     VS1  GIA   1525
# ..     ...   ...     ...  ...    ...
# 278   1.00     E    VVS1  HRD  14051
# 279   1.00     E    VVS2  HRD  11419
# 280   1.00     E     VS1  HRD  10588
# 281   1.00     F    VVS1  HRD  11696
# 282   1.00     F    VVS2  HRD  10588
# 283   1.00     G    VVS1  HRD  10450
# 284   1.00     G    VVS2  HRD   9896
# 285   1.00     G     VS2  HRD   9203
# 286   1.00     H    VVS1  HRD   9480
# 287   1.00     H     VS1  HRD   9065
# 288   1.00     H     VS2  HRD   8788
# 289   1.00     I    VVS1  HRD   8788
# 290   1.00     I    VVS2  HRD   8372
# 291   1.00     I     VS1  HRD   8095
# 292   1.00     I     VS2  HRD   7818
# 293   1.01     D    VVS2  HRD  13909
# 294   1.01     E    VVS2  HRD  11531
# 295   1.01     E     VS1  HRD  10692
# 296   1.01     F    VVS1  HRD  11811
# 297   1.01     F     VS1  HRD  10272
# 298   1.01     G    VVS2  HRD   9993
# 299   1.01     G     VS2  HRD   9293
# 300   1.01     H    VVS2  HRD   9433
# 301   1.01     H     VS1  HRD   9153
# 302   1.01     I    VVS1  HRD   8873
# 303   1.01     I     VS1  HRD   8175
# 304   1.02     F    VVS2  HRD  10796
# 305   1.06     H    VVS2  HRD   9890
# 306   1.02     H     VS2  HRD   8959
# 307   1.09     I    VVS2  HRD   9107
#
# [308 rows x 5 columns]

# %%
dia.head(10)
# Out:
#    CARAT COLOR CLARITY CERT  PRICE
# 0   0.30     D     VS2  GIA   1302
# 1   0.30     E     VS1  GIA   1510
# 2   0.30     G    VVS1  GIA   1510
# 3   0.30     G     VS1  GIA   1260
# 4   0.31     D     VS1  GIA   1641
# 5   0.31     E     VS1  GIA   1555
# 6   0.31     F     VS1  GIA   1427
# 7   0.31     G    VVS2  GIA   1427
# 8   0.31     H     VS2  GIA   1126
# 9   0.31     I     VS1  GIA   1126

# %%
# ?dia

# %%
dia.CARAT.mean()
# Out:
# 0.6309090909090909

# %%
dia.describe()
# Out:
#             CARAT         PRICE
# count  308.000000    308.000000
# mean     0.630909   5019.483766
# std      0.277183   3403.115715
# min      0.180000    638.000000
# 25%      0.350000   1625.000000
# 50%      0.620000   4215.000000
# 75%      0.850000   7446.000000
# max      1.100000  16008.000000

# %%
dia1=pd.DataFrame(dia)

# %%
dia1
# Out:
#      CARAT COLOR CLARITY CERT  PRICE
# 0     0.30     D     VS2  GIA   1302
# 1     0.30     E     VS1  GIA   1510
# 2     0.30     G    VVS1  GIA   1510
# 3     0.30     G     VS1  GIA   1260
# 4     0.31     D     VS1  GIA   1641
# 5     0.31     E     VS1  GIA   1555
# 6     0.31     F     VS1  GIA   1427
# 7     0.31     G    VVS2  GIA   1427
# 8     0.31     H     VS2  GIA   1126
# 9     0.31     I     VS1  GIA   1126
# 10    0.32     F     VS1  GIA   1468
# 11    0.32     G     VS2  GIA   1202
# 12    0.33     E     VS2  GIA   1327
# 13    0.33     I     VS2  GIA   1098
# 14    0.34     E     VS1  GIA   1693
# 15    0.34     F     VS1  GIA   1551
# 16    0.34     G     VS1  GIA   1410
# 17    0.34     G     VS2  GIA   1269
# 18    0.34     H     VS1  GIA   1316
# 19    0.34     H     VS2  GIA   1222
# 20    0.35     E     VS1  GIA   1738
# 21    0.35     F     VS1  GIA   1593
# 22    0.35     G     VS1  GIA   1447
# 23    0.35     H     VS2  GIA   1255
# 24    0.36     F     VS1  GIA   1635
# 25    0.36     H    VVS2  GIA   1485
# 26    0.37     F     VS2  GIA   1420
# 27    0.37     H     VS1  GIA   1420
# 28    0.40     F     VS1  GIA   1911
# 29    0.40     H     VS1  GIA   1525
# ..     ...   ...     ...  ...    ...
# 278   1.00     E    VVS1  HRD  14051
# 279   1.00     E    VVS2  HRD  11419
# 280   1.00     E     VS1  HRD  10588
# 281   1.00     F    VVS1  HRD  11696
# 282   1.00     F    VVS2  HRD  10588
# 283   1.00     G    VVS1  HRD  10450
# 284   1.00     G    VVS2  HRD   9896
# 285   1.00     G     VS2  HRD   9203
# 286   1.00     H    VVS1  HRD   9480
# 287   1.00     H     VS1  HRD   9065
# 288   1.00     H     VS2  HRD   8788
# 289   1.00     I    VVS1  HRD   8788
# 290   1.00     I    VVS2  HRD   8372
# 291   1.00     I     VS1  HRD   8095
# 292   1.00     I     VS2  HRD   7818
# 293   1.01     D    VVS2  HRD  13909
# 294   1.01     E    VVS2  HRD  11531
# 295   1.01     E     VS1  HRD  10692
# 296   1.01     F    VVS1  HRD  11811
# 297   1.01     F     VS1  HRD  10272
# 298   1.01     G    VVS2  HRD   9993
# 299   1.01     G     VS2  HRD   9293
# 300   1.01     H    VVS2  HRD   9433
# 301   1.01     H     VS1  HRD   9153
# 302   1.01     I    VVS1  HRD   8873
# 303   1.01     I     VS1  HRD   8175
# 304   1.02     F    VVS2  HRD  10796
# 305   1.06     H    VVS2  HRD   9890
# 306   1.02     H     VS2  HRD   8959
# 307   1.09     I    VVS2  HRD   9107
#
# [308 rows x 5 columns]

# %%
dia1.drop("CARAT", axis=1)
# Out:
#     COLOR CLARITY CERT  PRICE
# 0       D     VS2  GIA   1302
# 1       E     VS1  GIA   1510
# 2       G    VVS1  GIA   1510
# 3       G     VS1  GIA   1260
# 4       D     VS1  GIA   1641
# 5       E     VS1  GIA   1555
# 6       F     VS1  GIA   1427
# 7       G    VVS2  GIA   1427
# 8       H     VS2  GIA   1126
# 9       I     VS1  GIA   1126
# 10      F     VS1  GIA   1468
# 11      G     VS2  GIA   1202
# 12      E     VS2  GIA   1327
# 13      I     VS2  GIA   1098
# 14      E     VS1  GIA   1693
# 15      F     VS1  GIA   1551
# 16      G     VS1  GIA   1410
# 17      G     VS2  GIA   1269
# 18      H     VS1  GIA   1316
# 19      H     VS2  GIA   1222
# 20      E     VS1  GIA   1738
# 21      F     VS1  GIA   1593
# 22      G     VS1  GIA   1447
# 23      H     VS2  GIA   1255
# 24      F     VS1  GIA   1635
# 25      H    VVS2  GIA   1485
# 26      F     VS2  GIA   1420
# 27      H     VS1  GIA   1420
# 28      F     VS1  GIA   1911
# 29      H     VS1  GIA   1525
# ..    ...     ...  ...    ...
# 278     E    VVS1  HRD  14051
# 279     E    VVS2  HRD  11419
# 280     E     VS1  HRD  10588
# 281     F    VVS1  HRD  11696
# 282     F    VVS2  HRD  10588
# 283     G    VVS1  HRD  10450
# 284     G    VVS2  HRD   9896
# 285     G     VS2  HRD   9203
# 286     H    VVS1  HRD   9480
# 287     H     VS1  HRD   9065
# 288     H     VS2  HRD   8788
# 289     I    VVS1  HRD   8788
# 290     I    VVS2  HRD   8372
# 291     I     VS1  HRD   8095
# 292     I     VS2  HRD   7818
# 293     D    VVS2  HRD  13909
# 294     E    VVS2  HRD  11531
# 295     E     VS1  HRD  10692
# 296     F    VVS1  HRD  11811
# 297     F     VS1  HRD  10272
# 298     G    VVS2  HRD   9993
# 299     G     VS2  HRD   9293
# 300     H    VVS2  HRD   9433
# 301     H     VS1  HRD   9153
# 302     I    VVS1  HRD   8873
# 303     I     VS1  HRD   8175
# 304     F    VVS2  HRD  10796
# 305     H    VVS2  HRD   9890
# 306     H     VS2  HRD   8959
# 307     I    VVS2  HRD   9107
#
# [308 rows x 4 columns]

# %%
dia
# Out:
#      CARAT COLOR CLARITY CERT  PRICE
# 0     0.30     D     VS2  GIA   1302
# 1     0.30     E     VS1  GIA   1510
# 2     0.30     G    VVS1  GIA   1510
# 3     0.30     G     VS1  GIA   1260
# 4     0.31     D     VS1  GIA   1641
# 5     0.31     E     VS1  GIA   1555
# 6     0.31     F     VS1  GIA   1427
# 7     0.31     G    VVS2  GIA   1427
# 8     0.31     H     VS2  GIA   1126
# 9     0.31     I     VS1  GIA   1126
# 10    0.32     F     VS1  GIA   1468
# 11    0.32     G     VS2  GIA   1202
# 12    0.33     E     VS2  GIA   1327
# 13    0.33     I     VS2  GIA   1098
# 14    0.34     E     VS1  GIA   1693
# 15    0.34     F     VS1  GIA   1551
# 16    0.34     G     VS1  GIA   1410
# 17    0.34     G     VS2  GIA   1269
# 18    0.34     H     VS1  GIA   1316
# 19    0.34     H     VS2  GIA   1222
# 20    0.35     E     VS1  GIA   1738
# 21    0.35     F     VS1  GIA   1593
# 22    0.35     G     VS1  GIA   1447
# 23    0.35     H     VS2  GIA   1255
# 24    0.36     F     VS1  GIA   1635
# 25    0.36     H    VVS2  GIA   1485
# 26    0.37     F     VS2  GIA   1420
# 27    0.37     H     VS1  GIA   1420
# 28    0.40     F     VS1  GIA   1911
# 29    0.40     H     VS1  GIA   1525
# ..     ...   ...     ...  ...    ...
# 278   1.00     E    VVS1  HRD  14051
# 279   1.00     E    VVS2  HRD  11419
# 280   1.00     E     VS1  HRD  10588
# 281   1.00     F    VVS1  HRD  11696
# 282   1.00     F    VVS2  HRD  10588
# 283   1.00     G    VVS1  HRD  10450
# 284   1.00     G    VVS2  HRD   9896
# 285   1.00     G     VS2  HRD   9203
# 286   1.00     H    VVS1  HRD   9480
# 287   1.00     H     VS1  HRD   9065
# 288   1.00     H     VS2  HRD   8788
# 289   1.00     I    VVS1  HRD   8788
# 290   1.00     I    VVS2  HRD   8372
# 291   1.00     I     VS1  HRD   8095
# 292   1.00     I     VS2  HRD   7818
# 293   1.01     D    VVS2  HRD  13909
# 294   1.01     E    VVS2  HRD  11531
# 295   1.01     E     VS1  HRD  10692
# 296   1.01     F    VVS1  HRD  11811
# 297   1.01     F     VS1  HRD  10272
# 298   1.01     G    VVS2  HRD   9993
# 299   1.01     G     VS2  HRD   9293
# 300   1.01     H    VVS2  HRD   9433
# 301   1.01     H     VS1  HRD   9153
# 302   1.01     I    VVS1  HRD   8873
# 303   1.01     I     VS1  HRD   8175
# 304   1.02     F    VVS2  HRD  10796
# 305   1.06     H    VVS2  HRD   9890
# 306   1.02     H     VS2  HRD   8959
# 307   1.09     I    VVS2  HRD   9107
#
# [308 rows x 5 columns]

# %%
# Out:
#           CARAT     PRICE
# CARAT  1.000000  0.944727
# PRICE  0.944727  1.000000

# %%
dia.CARAT.plot(kind='line', color='k', alpha=0.7)

# %%
plt.scatter(dia.CARAT, dia.PRICE)
